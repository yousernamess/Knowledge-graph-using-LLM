# %% [markdown]
# ## Libraries

# %%
#main
import pandas as pd
import numpy as np
import os
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.document_loaders import PyPDFDirectoryLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pathlib import Path
import random

#helpers
import uuid
import pandas as pd
import numpy as np


#loader
from bs4 import BeautifulSoup
import requests
from langchain_core.documents import Document

# %% [markdown]
# ## Load Documents from an HTML File

# %%
# loaders.py

def load_from_html(url: str) -> list:
    """Fetch and parse an HTML page, return content as LangChain-style Document objects."""
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")

    # You can tweak this selector logic to suit your use case
    content_blocks = soup.find_all(["p", "div", "article", "section"])
    documents = []

    for i, block in enumerate(content_blocks):
        text = block.get_text(strip=True)
        if text:
            documents.append(Document(page_content=text, metadata={"source": url, "block_id": i}))

    return documents

# %%
from readability import Document as ReadabilityDoc
import requests
from bs4 import BeautifulSoup
from langchain_core.documents import Document

def load_readable_html(url: str) -> list:
    html = requests.get(url).text
    readable_article = ReadabilityDoc(html).summary()
    soup = BeautifulSoup(readable_article, "html.parser")
    paragraphs = soup.find_all("p")
    docs = []
    for i, p in enumerate(paragraphs):
        text = p.get_text(strip=True)
        if len(text) > 50:
            docs.append(Document(page_content=text, metadata={"source": url, "block_id": i}))
    return docs

# %%
WEBPAGE_URL = "https://en.wikipedia.org/wiki/Wikipedia"


docs = load_readable_html(WEBPAGE_URL)


splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,
    chunk_overlap=150,
    length_function=len,
    is_separator_regex=False,
)
pages = splitter.split_documents(docs)

print("Number of chunks:", len(pages))
# Out:
# Number of chunks: 142

# %% [markdown]
# ## Document to dataframe

# %%
def documents2Dataframe(documents) -> pd.DataFrame:
    rows = []
    for chunk in documents:
        row = {
            "text": chunk.page_content,
            **chunk.metadata,
            "chunk_id": uuid.uuid4().hex,
        }
        rows = rows + [row]

    df = pd.DataFrame(rows)
    return df

def extractConcepts(dataframe: pd.DataFrame, model=None) -> list:
    # dataframe.reset_index(inplace=True)
    results = dataframe.apply(
        lambda row: graphPrompt(row.text, {"chunk_id": row.chunk_id}, model), axis=1
    )
    # invalid json results in NaN
    results = results.dropna()
    results = results.reset_index(drop=True)

    ## Flatten the list of lists to one single list of entities.
    concept_list = np.concatenate(results).ravel().tolist()
    return concept_list


def cleanConcepts2df(nodes_list) -> pd.DataFrame:
    ## Remove all NaN entities
    graph_dataframe = pd.DataFrame(nodes_list).replace(" ", np.nan)
    graph_dataframe = graph_dataframe.dropna(subset=["node_1", "node_2"])
    graph_dataframe["node_1"] = graph_dataframe["node_1"].apply(lambda x: x.lower())
    graph_dataframe["node_2"] = graph_dataframe["node_2"].apply(lambda x: x.lower())

    return graph_dataframe

# %%
df = documents2Dataframe(pages)
print(df.shape)

pd.set_option("display.max_rows", None)  # Show all rows
pd.set_option("display.max_columns", None)  # Show all columns
pd.set_option("display.width", None)  # No limit on width
pd.set_option("display.max_colwidth", None)  # No limit on column width

df.head()

# print(df.apply(lambda row: print(row.text), axis=1))
# Out:
# (142, 4)
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  text  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Wikipedia[b]is afreeonlineencyclopedia, written and maintained by a community ofvolunteers, known asWikipedians, throughopen collaborationand thewikisoftwareMediaWiki. Founded byJimmy WalesandLarry Sangeron January 15, 2001, Wikipedia has been hosted since 2003 by theWikimedia Foundation, an Americannonprofit organizationfunded mainly by donations from readers.[2]Wikipedia is the largest and most-readreference workin history.[3][4]
# 1                                                                                                                                                                                                                                                                                                                                                                                                        Initially available only in English, Wikipedia now existsin over 340 languages. TheEnglish Wikipedia, with over 6 millionarticles, remains the largest of the editions, which together comprise more than 64 million articles and attract more than 1.5 billion unique device visits and 13 million edits per month (about 5edits per second on average)  as of April 2024[update].[W 1]As of March 2025[update], over 25% of Wikipedia'strafficcomes from theUnited States, followed byJapanat 6.38%, theUnited Kingdomat 5.81%,Germanyat 4.97%,Russiaat 4.86%, and the remaining 52.25% split among all othercountries.[5]
# 2                                                                                                                                                                                              Wikipedia has been praised for enabling thedemocratization of knowledge, its extensive coverage, unique structure, and culture.Wikipedia has been censoredby some national governments, ranging from specific pages to the entire site.[6][7]Although Wikipedia's volunteer editors have written extensively on a wide variety of topics,the encyclopedia has been criticizedforsystemic bias, such as agender biasagainst women andgeographical biasagainst theGlobal South(Eurocentrism).[8][9]While thereliability of Wikipediawas frequently criticized in the 2000s, it has improved over time, receiving greater praise from the late 2010s onward,[3][10][11]while becomingan important fact-checking site.[12][13]Articles onbreaking newsare often accessed as sources for up-to-date information about those events.[14][15]
# 3  Various collaborative online encyclopedias were attempted before the start of Wikipedia, but with limited success.[16]Wikipedia began as a complementary project for Nupedia, a free online English-language encyclopedia project whose articles were written by experts and reviewed under a formal process.[17]It was founded on March 9, 2000, under the ownership ofBomis, aweb portalcompany. Its main figures were Bomis CEOJimmy WalesandLarry Sanger, editor-in-chief for Nupedia and later Wikipedia.[1][18]Nupedia was initially licensed under its own NupediaOpen ContentLicense, but before Wikipedia was founded, Nupedia switched to theGNU Free Documentation Licenseat the urging ofRichard Stallman.[W 2]Wales is credited with defining the goal of making a publicly editable encyclopedia,[19][W 3]while Sanger is credited with the strategy of using awikito reach that goal.[W 4]On January 10, 2001, Sanger proposed on the Nupedia mailing list to create a wiki as a "feeder" project for Nupedia.[W 5]
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Wikipedia was launched on January 15, 2001[17](referred to asWikipedia Day) as a singleEnglish languageedition with the domain namewww.wikipedia.com,[W 6]and was announced by Sanger on the Nupedia mailing list.[19]The name originated from ablendof the wordswikiandencyclopedia.[20][21]Its integral policy of "neutral point-of-view"[W 7]was codified in its first few months. Otherwise, there were initially relatively few rules, and it operated independently of Nupedia.[19]Bomis originally intended for it to be a for-profit business.[22]
#
#                                     source  block_id  \
# 0  https://en.wikipedia.org/wiki/Wikipedia         2
# 1  https://en.wikipedia.org/wiki/Wikipedia         3
# 2  https://en.wikipedia.org/wiki/Wikipedia         4
# 3  https://en.wikipedia.org/wiki/Wikipedia         7
# 4  https://en.wikipedia.org/wiki/Wikipedia         9
#
#                            chunk_id
# 0  ca39ec7af23f47d0ad6561e668897fff
# 1  2493ffd6ee7940faa94105ec83d95c1e
# 2  869781f63b3247339f4d20a135f504a8
# 3  1548bfa7f06045b6ae0937aa3fe90119
# 4  4b95de49d8244dcb8603b450068ba67c

# %% [markdown]
# ## Extract Concepts from the Dataframe

# %% [markdown]
# !!The ollama.client doesnt work because client is a file in the main file!!

# %%
import sys
from yachalk import chalk
sys.path.append("..")

import json
import ollama


def graphPrompt(input: str, metadata={}, model="mistral-openorca:latest"):
    if model == None:
        model = "mistral-openorca:latest"



    # SYS_PROMPT = (
    #     "You are a network graph maker who extracts terms and their relations from a given context. "
    #     "You are provided with a context chunk (delimited by ```) Your task is to extract the ontology "
    #     "of terms mentioned in the given context. These terms should represent the key concepts as per the context. \n"
    #     "Thought 1: While traversing through each sentence, Think about the key terms mentioned in it.\n"
    #         "\tTerms may include object, entity, location, organization, person, \n"
    #         "\tcondition, acronym, documents, service, concept, etc.\n"
    #         "\tTerms should be as atomistic as possible\n\n"
    #     "Thought 2: Think about how these terms can have one on one relation with other terms.\n"
    #         "\tTerms that are mentioned in the same sentence or the same paragraph are typically related to each other.\n"
    #         "\tTerms can be related to many other terms\n\n"
    #     "Thought 3: Find out the relation between each such related pair of terms. \n\n"
    #     "Format your output as a list of json. Each element of the list contains a pair of terms"
    #     "and the relation between them, like the follwing: \n"
    #     "[\n"
    #     "   {\n"
    #     '       "node_1": "A concept from extracted ontology",\n'
    #     '       "node_2": "A related concept from extracted ontology",\n'
    #     '       "edge": "relationship between the two concepts, node_1 and node_2 in one or two sentences"\n'
    #     "   }, {...}\n"
    #     "]"
    # )

    USER_PROMPT = f"context: ```{input}``` \n\n output: "
    response = ollama.chat(model="kg_good", messages=[ {"role": "user", "content": USER_PROMPT}], options={"use_gpu": True})

    try:

        result = json.loads(response['message']['content'])  
        result = [dict(item, **metadata) for item in result]
    except Exception as e:
        print("\n\nERROR ### Here is the buggy response: ", response, "\n\n")
        print("Exception:", str(e))
        result = None

    return result

# %%
## To regenerate the graph with LLM, set this to True
regenerate = False

if regenerate:
    concepts_list = extractConcepts(df, model='zephyr:latest')
    dfg1 = cleanConcepts2df(concepts_list)
    if not os.path.exists(outputdirectory):
        os.makedirs(outputdirectory)
    
    dfg1.to_csv(outputdirectory/"graph.csv", sep="|", index=False)
    df.to_csv(outputdirectory/"chunks.csv", sep="|", index=False)
else:
    dfg1 = pd.read_csv(outputdirectory/"graph.csv", sep="|")

dfg1.replace("", np.nan, inplace=True)
dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
dfg1['count'] = 10
## Increasing the weight of the relation to 4. 
## We will assign the weight of 1 when later the contextual proximity will be calculated.  
pd.set_option("display.max_rows", None)  # Show all rows
pd.set_option("display.max_columns", None)  # Show all columns
pd.set_option("display.width", None)  # No limit on width
pd.set_option("display.max_colwidth", None)  # No limit on column width
print(dfg1.shape)
dfg1.head()
# Out:
# (52, 5)
#                                            node_1  \
# 0                                               1
# 1                                               1
# 2                                    introduction
# 3  brief history of virtual unwrapping techniques
# 4                                    how it works
#
#                           node_2                     edge  \
# 0                         number           represented as
# 1                         single  indicated a single unit
# 2  virtual unwrapping techniques                  covered
# 3  virtual unwrapping techniques               related to
# 4  virtual unwrapping techniques                explained
#
#                            chunk_id  count
# 0  5a6ec9a2868449f787cbbd04d229fe70     10
# 1  5a6ec9a2868449f787cbbd04d229fe70     10
# 2  453a9cb6de4d459ca97edff5ab9aee69     10
# 3  453a9cb6de4d459ca97edff5ab9aee69     10
# 4  453a9cb6de4d459ca97edff5ab9aee69     10

# %%
def contextual_proximity(df: pd.DataFrame) -> pd.DataFrame:
    ## Melt the dataframe into a list of nodes
    dfg_long = pd.melt(
        df, id_vars=["chunk_id"], value_vars=["node_1", "node_2"], value_name="node"
    )
    dfg_long.drop(columns=["variable"], inplace=True)
    # Self join with chunk id as the key will create a link between terms occuring in the same text chunk.
    dfg_wide = pd.merge(dfg_long, dfg_long, on="chunk_id", suffixes=("_1", "_2"))
    # drop self loops
    self_loops_drop = dfg_wide[dfg_wide["node_1"] == dfg_wide["node_2"]].index
    dfg2 = dfg_wide.drop(index=self_loops_drop).reset_index(drop=True)
    ## Group and count edges.
    dfg2 = (
        dfg2.groupby(["node_1", "node_2"])
        .agg({"chunk_id": [",".join, "count"]})
        .reset_index()
    )
    dfg2.columns = ["node_1", "node_2", "chunk_id", "count"]
    dfg2.replace("", np.nan, inplace=True)
    dfg2.dropna(subset=["node_1", "node_2"], inplace=True)
    # Drop edges with 1 count
    dfg2 = dfg2[dfg2["count"] != 1]
    dfg2["edge"] = "contextual proximity"
    return dfg2


dfg2 = contextual_proximity(dfg1)
dfg2.tail()
# Out:
#                              node_1              node_2  \
# 969  x-ray computed tomography (ct)  virtual unwrapping
# 971                   x-ray ct scan          algorithms
# 982                   x-ray ct scan            research
# 986                   x-ray ct scan  virtual unwrapping
# 994                    x-ray source            scanning
#
#                                                                                                                                                                  chunk_id  \
# 969  0788cec8ead6448d8476a3f54174f34d,0788cec8ead6448d8476a3f54174f34d,0788cec8ead6448d8476a3f54174f34d,0788cec8ead6448d8476a3f54174f34d,0788cec8ead6448d8476a3f54174f34d
# 971                                                                                                     96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5
# 982                                                                    96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5
# 986  96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5
# 994                                                                    88f48d8de0b84cb690c4211e7db00389,88f48d8de0b84cb690c4211e7db00389,88f48d8de0b84cb690c4211e7db00389
#
#      count                  edge
# 969      5  contextual proximity
# 971      2  contextual proximity
# 982      3  contextual proximity
# 986      5  contextual proximity
# 994      3  contextual proximity

# %% [markdown]
# ## Merge both dataframes

# %%
dfg = pd.concat([dfg1, dfg2], axis=0)
dfg = (
    dfg.groupby(["node_1", "node_2"])
    .agg({"chunk_id": ",".join, "edge": ','.join, 'count': 'sum'})
    .reset_index()
)
dfg
# dfg = pd.concat([dfg1, dfg2], axis=0, ignore_index=True)

# dfg = dfg.groupby(["node_1", "node_2"], as_index=False).agg({
#     "chunk_id": ",".join, 
#     "edge": lambda x: ','.join(set(x)),  # Avoid duplicate edges in text
#     "count": "sum"  # Ensure the count is properly accumulated
# })
# dfg
# Out:
#                                              node_1  \
# 0                                                 1
# 1                                                 1
# 2                                          3d image
# 3                                                 6
# 4                               advanced algorithms
# 5                               advanced algorithms
# 6                                         algorithm
# 7                                         algorithm
# 8                                        algorithms
# 9                                        algorithms
# 10                                       algorithms
# 11                                       algorithms
# 12                                       algorithms
# 13                                       algorithms
# 14                                       algorithms
# 15                                       algorithms
# 16                                       algorithms
# 17                                       algorithms
# 18                                       algorithms
# 19                                       algorithms
# 20                                       algorithms
# 21                                       algorithms
# 22                                       algorithms
# 23                                       algorithms
# 24                                         analysis
# 25                                         analysis
# 26                                         analysis
# 27                                         analysis
# 28                                       archeology
# 29                                        artifacts
# 30                                        artifacts
# 31                                        artifacts
# 32                                        artifacts
# 33                                        artifacts
# 34                                        artifacts
# 35   brief history of virtual unwrapping techniques
# 36                                       conclusion
# 37                conservation of cultural heritage
# 38                                         contrast
# 39                                       ct imaging
# 40                               cultural artifacts
# 41                               cultural artifacts
# 42                               cultural artifacts
# 43                         deep learning algorithms
# 44                         deep learning algorithms
# 45                         deep learning algorithms
# 46                         deep learning algorithms
# 47                  delicate writings and artifacts
# 48                               digital algorithms
# 49                                digital procedure
# 50                digital reconstruction algorithms
# 51                             faint text or images
# 52                                forensic medicine
# 53                                forensic medicine
# 54                                forensic medicine
# 55                                    fragile items
# 56                              herculaneum scrolls
# 57                              herculaneum scrolls
# 58                           hidden text or details
# 59                             historical knowledge
# 60                             historical knowledge
# 61                             historical knowledge
# 62                                     how it works
# 63                      image processing techniques
# 64                                           images
# 65                                           images
# 66                                           images
# 67                                           images
# 68                                           images
# 69                                           images
# 70                                           images
# 71                                           images
# 72                             imaging technologies
# 73                             imaging technologies
# 74                             imaging technologies
# 75                                     ink deposits
# 76                                     ink deposits
# 77                                          innards
# 78                                          innards
# 79                                     intelligence
# 80                                     intelligence
# 81                                     intelligence
# 82                                        intensity
# 83                                        intensity
# 84                       internal structure imaging
# 85                       internal structure imaging
# 86                                     introduction
# 87                                           layers
# 88                                           layers
# 89                                           layers
# 90                                           layers
# 91                                           layers
# 92                                           layers
# 93                                           layers
# 94                                           layers
# 95                                           layers
# 96                                           layers
# 97                                           layers
# 98                                           layers
# 99                                           layers
# 100                                          layers
# 101                              layers of interest
# 102                              layers of interest
# 103                                  layers of text
# 104                                  layers of text
# 105                                  layers of text
# 106                                  layers of text
# 107                                  layers of text
# 108                                  layers of text
# 109                      layers within scanned data
# 110                                          limits
# 111                                          limits
# 112                                          limits
# 113                                machine learning
# 114                                machine learning
# 115                            material composition
# 116                            material composition
# 117                            material composition
# 118                            material composition
# 119                            material composition
# 120                            material composition
# 121                                 medical imaging
# 122                                        micro-ct
# 123                                        micro-ct
# 124                                          number
# 125                                          object
# 126                                          object
# 127                                         objects
# 128                                         objects
# 129                                         objects
# 130                                         objects
# 131                                         objects
# 132                                         objects
# 133                                         objects
# 134                                         objects
# 135                                         objects
# 136                               physical handling
# 137                                 physical layers
# 138                                      references
# 139                                        research
# 140                                        research
# 141                                        research
# 142                                        research
# 143                                        research
# 144                                        research
# 145                                        research
# 146                                        research
# 147                                        research
# 148                                        research
# 149                                        research
# 150                                        research
# 151                                        research
# 152                                        research
# 153                                        research
# 154                                        research
# 155                                      researcher
# 156                                      researcher
# 157                                      researcher
# 158                                      researcher
# 159                                     researchers
# 160                                     researchers
# 161                                     researchers
# 162                                     researchers
# 163                                     researchers
# 164                                     researchers
# 165                          resolution limitations
# 166                          resolution limitations
# 167                          resolution limitations
# 168                                    scanned data
# 169                                        scanning
# 170                                        scanning
# 171                                        scanning
# 172                                        scanning
# 173                                        scanning
# 174                                        scanning
# 175                                        scanning
# 176                                        scanning
# 177                                        scanning
# 178                                        scanning
# 179                                        scanning
# 180                             scientific research
# 181                             scientific research
# 182                             scientific research
# 183                                    sealed items
# 184                  segmentation & layer detection
# 185                  segmentation & layer detection
# 186                                          single
# 187                           synchrotron radiation
# 188                           synchrotron radiation
# 189                               tangible contents
# 190                               tangible contents
# 191                                         texture
# 192                                 texture mapping
# 193                                 texture mapping
# 194                                          unwrap
# 195                                          unwrap
# 196                                          unwrap
# 197                                          unwrap
# 198                                          unwrap
# 199                                  virtual layers
# 200                                  virtual layers
# 201                              virtual unwrapping
# 202                              virtual unwrapping
# 203                              virtual unwrapping
# 204                              virtual unwrapping
# 205                              virtual unwrapping
# 206                              virtual unwrapping
# 207                              virtual unwrapping
# 208                              virtual unwrapping
# 209                              virtual unwrapping
# 210                              virtual unwrapping
# 211                              virtual unwrapping
# 212                              virtual unwrapping
# 213                              virtual unwrapping
# 214                              virtual unwrapping
# 215                              virtual unwrapping
# 216                              virtual unwrapping
# 217                              virtual unwrapping
# 218                              virtual unwrapping
# 219                              virtual unwrapping
# 220                              virtual unwrapping
# 221                              virtual unwrapping
# 222                              virtual unwrapping
# 223                              virtual unwrapping
# 224                              virtual unwrapping
# 225                              virtual unwrapping
# 226                              virtual unwrapping
# 227                              virtual unwrapping
# 228                              virtual unwrapping
# 229                              virtual unwrapping
# 230                              virtual unwrapping
# 231                              virtual unwrapping
# 232                              virtual unwrapping
# 233                              virtual unwrapping
# 234                              virtual unwrapping
# 235                   virtual unwrapping techniques
# 236                   virtual unwrapping techniques
# 237                   virtual unwrapping techniques
# 238                   virtual unwrapping techniques
# 239                   virtual unwrapping techniques
# 240                      wildlife detection systems
# 241                               writing materials
# 242                  x-ray computed tomography (ct)
# 243                                   x-ray ct scan
# 244                                   x-ray ct scan
# 245                                   x-ray ct scan
# 246                                    x-ray source
# 247                                    x-ray source
#
#                                              node_2  \
# 0                                            number
# 1                                            single
# 2                                          scanning
# 3                                                 4
# 4                        layers within scanned data
# 5                                          scanning
# 6                                          contrast
# 7                                            layers
# 8                                          analysis
# 9                                cultural artifacts
# 10                         deep learning algorithms
# 11                                forensic medicine
# 12                             historical knowledge
# 13                                           images
# 14                             imaging technologies
# 15                                     intelligence
# 16                                           limits
# 17                                          objects
# 18                                         research
# 19                                       researcher
# 20                           resolution limitations
# 21                              scientific research
# 22                               virtual unwrapping
# 23                                    x-ray ct scan
# 24                                       algorithms
# 25                                           limits
# 26                                         research
# 27                               virtual unwrapping
# 28                               virtual unwrapping
# 29                                           images
# 30                                   layers of text
# 31                             material composition
# 32                                          objects
# 33                                      researchers
# 34                                           unwrap
# 35                    virtual unwrapping techniques
# 36                    virtual unwrapping techniques
# 37                               virtual unwrapping
# 38                                           layers
# 39                                         scanning
# 40                                       algorithms
# 41                                         research
# 42                               virtual unwrapping
# 43                                       algorithms
# 44                             imaging technologies
# 45                                         research
# 46                               virtual unwrapping
# 47                               virtual unwrapping
# 48                                           layers
# 49                               virtual unwrapping
# 50                               virtual unwrapping
# 51                                         scanning
# 52                                       algorithms
# 53                                         research
# 54                               virtual unwrapping
# 55                               virtual unwrapping
# 56                  delicate writings and artifacts
# 57                               virtual unwrapping
# 58                                           layers
# 59                                       algorithms
# 60                                         research
# 61                               virtual unwrapping
# 62                    virtual unwrapping techniques
# 63                                           layers
# 64                                       algorithms
# 65                                        artifacts
# 66                                   layers of text
# 67                             material composition
# 68                                          objects
# 69                                         research
# 70                                      researchers
# 71                               virtual unwrapping
# 72                                       algorithms
# 73                                         research
# 74                               virtual unwrapping
# 75                                           layers
# 76                                          texture
# 77                                    fragile items
# 78                               virtual unwrapping
# 79                                       algorithms
# 80                                         research
# 81                               virtual unwrapping
# 82                                           layers
# 83                                writing materials
# 84                digital reconstruction algorithms
# 85                               virtual unwrapping
# 86                    virtual unwrapping techniques
# 87                                        algorithm
# 88                                         contrast
# 89                               digital algorithms
# 90                           hidden text or details
# 91                      image processing techniques
# 92                                     ink deposits
# 93                                        intensity
# 94                               layers of interest
# 95                                 machine learning
# 96                                           object
# 97                                  physical layers
# 98                                          texture
# 99                                   virtual layers
# 100                               writing materials
# 101                              digital algorithms
# 102                                          layers
# 103                                       artifacts
# 104                                          images
# 105                            material composition
# 106                                         objects
# 107                                     researchers
# 108                                          unwrap
# 109                                        scanning
# 110                                      algorithms
# 111                                        research
# 112                              virtual unwrapping
# 113                     image processing techniques
# 114                                          layers
# 115                                       artifacts
# 116                                          images
# 117                                  layers of text
# 118                                         objects
# 119                                     researchers
# 120                                          unwrap
# 121                              virtual unwrapping
# 122                              virtual unwrapping
# 123                  x-ray computed tomography (ct)
# 124                                               1
# 125                                          layers
# 126                                        scanning
# 127                                      algorithms
# 128                                       artifacts
# 129                                          images
# 130                                  layers of text
# 131                            material composition
# 132                                        research
# 133                                     researchers
# 134                                          unwrap
# 135                              virtual unwrapping
# 136                              virtual unwrapping
# 137                                          layers
# 138                   virtual unwrapping techniques
# 139                                      algorithms
# 140                                        analysis
# 141                              cultural artifacts
# 142                        deep learning algorithms
# 143                               forensic medicine
# 144                            historical knowledge
# 145                                          images
# 146                            imaging technologies
# 147                                    intelligence
# 148                                          limits
# 149                                         objects
# 150                                      researcher
# 151                          resolution limitations
# 152                             scientific research
# 153                              virtual unwrapping
# 154                                   x-ray ct scan
# 155                                      algorithms
# 156                                         objects
# 157                                        research
# 158                              virtual unwrapping
# 159                                       artifacts
# 160                                          images
# 161                                  layers of text
# 162                            material composition
# 163                                         objects
# 164                                          unwrap
# 165                                      algorithms
# 166                                        research
# 167                              virtual unwrapping
# 168                                        scanning
# 169                                        3d image
# 170                             advanced algorithms
# 171                                      ct imaging
# 172                            faint text or images
# 173                      layers within scanned data
# 174                                          object
# 175                                    scanned data
# 176                  segmentation & layer detection
# 177                                 texture mapping
# 178                              virtual unwrapping
# 179                                    x-ray source
# 180                                      algorithms
# 181                                        research
# 182                              virtual unwrapping
# 183                              virtual unwrapping
# 184                                    scanned data
# 185                                        scanning
# 186                                               1
# 187                              virtual unwrapping
# 188                      wildlife detection systems
# 189                                    sealed items
# 190                              virtual unwrapping
# 191                                          layers
# 192                            faint text or images
# 193                                        scanning
# 194                                       artifacts
# 195                                  layers of text
# 196                            material composition
# 197                                         objects
# 198                                     researchers
# 199                                          layers
# 200                                 physical layers
# 201                                      algorithms
# 202                                        analysis
# 203                                      archeology
# 204               conservation of cultural heritage
# 205                              cultural artifacts
# 206                        deep learning algorithms
# 207                 delicate writings and artifacts
# 208                               digital procedure
# 209               digital reconstruction algorithms
# 210                               forensic medicine
# 211                                   fragile items
# 212                             herculaneum scrolls
# 213                            historical knowledge
# 214                                          images
# 215                            imaging technologies
# 216                                         innards
# 217                                    intelligence
# 218                      internal structure imaging
# 219                                          limits
# 220                                 medical imaging
# 221                                        micro-ct
# 222                                         objects
# 223                               physical handling
# 224                                        research
# 225                                      researcher
# 226                          resolution limitations
# 227                                        scanning
# 228                             scientific research
# 229                                    sealed items
# 230                           synchrotron radiation
# 231                               tangible contents
# 232                      wildlife detection systems
# 233                  x-ray computed tomography (ct)
# 234                                   x-ray ct scan
# 235  brief history of virtual unwrapping techniques
# 236                                      conclusion
# 237                                    how it works
# 238                                    introduction
# 239                                      references
# 240                              virtual unwrapping
# 241                                          layers
# 242                              virtual unwrapping
# 243                                      algorithms
# 244                                        research
# 245                              virtual unwrapping
# 246                                          object
# 247                                        scanning
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             chunk_id  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                 5a6ec9a2868449f787cbbd04d229fe70,5a6ec9a2868449f787cbbd04d229fe70,5a6ec9a2868449f787cbbd04d229fe70
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                 5a6ec9a2868449f787cbbd04d229fe70,5a6ec9a2868449f787cbbd04d229fe70,5a6ec9a2868449f787cbbd04d229fe70
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                 88f48d8de0b84cb690c4211e7db00389,88f48d8de0b84cb690c4211e7db00389,88f48d8de0b84cb690c4211e7db00389
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   9fe9dfea575147fca818074c003d84a3
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   88f48d8de0b84cb690c4211e7db00389
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                 88f48d8de0b84cb690c4211e7db00389,88f48d8de0b84cb690c4211e7db00389,88f48d8de0b84cb690c4211e7db00389
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   5e6c95b9fcd24c0c8d18cb6756e91713
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  5e6c95b9fcd24c0c8d18cb6756e91713,5e6c95b9fcd24c0c8d18cb6756e91713
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5
# 18                                                                                                                                                                                                                                                                                                                                             96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5
# 22                                                                                                                                                                                                         96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  96e305fc48d946daab61df9d5c64d1b5
# 26                                                                                                                                                                                                                                                                                                                                                                                                                                                96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5
# 27                                                                                                                                                                                                                                                                                                                                                                              96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5,96e305fc48d946daab61df9d5c64d1b5
# 28                                                                                                                                                                                                                                                                                                                                                                              0788cec8ead6448d8476a3f54174f34d,0788cec8ead6448d8476a3f54174f34d,0788cec8ead6448d8476a3f54174f34d,0788cec8ead6448d8476a3f54174f34d,0788cec8ead6448d8476a3f54174f34d
# 29                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 45044d5cf6324f1da33224ddba9d7255,45044d5cf6324f1da33224ddba9d7255
# 30                                                                                                                                                                                                                                                                                                                                                                                                               45044d5cf6324f1da33224ddba9d7255,45044d5cf6324f1da33224ddba9d7255,45044d5cf6324f1da33224ddba9d7255,45044d5cf6324f1da33224ddba9d7255
# 31                                                                                                                                                                                                                                                                                                                                                                                                               45044d5cf6324f1da33224ddba9d7255,45044d5cf6324f1da33224ddba9d7255,45044d5cf6324f1da33224ddba9d7255,45044d5cf6324f1da33224ddba9d7255
# 32                                                                                                                                                                                                                                                                                                                                                                                                               45044d5cf6324f1da33224ddba9d7255,45044d5cf6324f1da33224ddba9d7255,45044d5cf6324f1da33224ddba9d7255,45044d5cf6324f1da33224ddba9d7255
# 33                                                                                                                                                                                                                                                                                                                                                                                                               45044d5cf6324f1da33224ddba9d7255,45044d5cf6324f1da33224ddba9d7255,45044d5cf6324f1da33224ddba9d7255,45044d5cf6324f1da33224ddba9d7255
# 34                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 45044d5cf6324f1da33224ddba9d7255,45044d5cf6324f1da33224ddba9d7255
# 35                                                                                                                                                                                                                                                                                                                                             453a9cb6de4d459ca97edff5ab9aee69,453a9cb6de4d459ca97edff5ab9aee69,453a9cb6de4d459ca97edff5ab9aee69,453a9cb6de4d459ca97edff5ab9aee69,453a9cb6de4d459ca97edff5ab9aee69,453a9cb6de4d459ca97edff5ab9aee69
# 36                                                                                                                                                                                                                                                                                                                                             453a9cb6de4d459ca97edff5ab9aee69,453a9cb6de4d459ca97edff5ab9aee69,453a9cb6de4d459ca97edff5ab9aee69,453a9cb6de4d459ca97edff5ab9aee69,453a9cb6de4d459ca97edff5ab9aee69,453a9cb6de4d459ca97edff5ab9aee69
# ...
# 247                                                                                                                                                                                                                                                                                                                                                                                                                                               88f48d8de0b84cb690c4211e7db00389,88f48d8de0b84cb690c4211e7db00389,88f48d8de0b84cb690c4211e7db00389
#
#                                                 edge  count
# 0                represented as,contextual proximity     12
# 1       indicated a single unit,contextual proximity     12
# 2                               contextual proximity      3
# 3                                       divided into     10
# 4                                           identify     10
# 5                               contextual proximity      3
# 6                                           achieved     10
# 7                               contextual proximity      2
# 8                               contextual proximity      2
# 9                               contextual proximity      2
# 10                              contextual proximity      2
# 11                              contextual proximity      2
# 12                              contextual proximity      2
# 13                              contextual proximity      2
# 14                              contextual proximity      2
# 15                   related to,contextual proximity     12
# 16                              contextual proximity      2
# 17                              contextual proximity      2
# 18                              contextual proximity      6
# 19                              contextual proximity      2
# 20                              contextual proximity      2
# 21                              contextual proximity      2
# 22                              contextual proximity     10
# 23                              contextual proximity      2
# 24                              contextual proximity      2
# 25                                            pushed     10
# 26                              contextual proximity      3
# 27                              contextual proximity      5
# 28                              contextual proximity      5
# 29                              contextual proximity      2
# 30                              contextual proximity      4
# 31                              contextual proximity      4
# 32                              contextual proximity      4
# 33                              contextual proximity      4
# 34                              contextual proximity      2
# 35                   related to,contextual proximity     15
# 36                   summarized,contextual proximity     15
# 37                              contextual proximity      5
# 38                              contextual proximity      2
# 39                              contextual proximity      3
# 40                              contextual proximity      2
# 41                              contextual proximity      3
# 42                              contextual proximity      5
# 43                              contextual proximity      2
# 44                                       advances in     10
# 45                              contextual proximity      3
# 46                              contextual proximity      5
# 47                              contextual proximity      5
# 48                              contextual proximity      2
# 49                              contextual proximity      5
# 50                              contextual proximity      5
# 51                              contextual proximity      3
# 52                              contextual proximity      2
# 53                      studied,contextual proximity     13
# 54                              contextual proximity      5
# 55                              contextual proximity      5
# 56                                   are examples of     10
# 57                              contextual proximity      5
# 58                              contextual proximity      2
# 59                              contextual proximity      2
# 60                              contextual proximity      3
# 61                              contextual proximity      5
# 62                    explained,contextual proximity     15
# 63                              contextual proximity      2
# 64                 derived from,contextual proximity     12
# 65                              contextual proximity      2
# 66                              contextual proximity      2
# 67                              contextual proximity      2
# 68                              contextual proximity      3
# 69                              contextual proximity      3
# 70                              contextual proximity      2
# 71                              contextual proximity      5
# 72                              contextual proximity      2
# 73                              contextual proximity      3
# 74                              contextual proximity      5
# 75                              contextual proximity      2
# 76                            superimposed digitally     10
# 77                                    can be studied     10
# 78                              contextual proximity      5
# 79                              contextual proximity      2
# 80                              contextual proximity      3
# 81                              contextual proximity      5
# 82                              contextual proximity      2
# 83                                     correlated to     10
# 84                               can be empowered by     10
# 85                              contextual proximity      5
# 86                      covered,contextual proximity     15
# 87                              contextual proximity      2
# 88                              contextual proximity      2
# 89                              contextual proximity      2
# 90                     contains,contextual proximity     12
# 91                              contextual proximity      2
# 92                              contextual proximity      2
# 93                              contextual proximity      2
# 94                              contextual proximity      2
# 95                              contextual proximity      2
# 96                              contextual proximity      2
# 97                              contextual proximity      2
# 98                              contextual proximity      2
# 99                              contextual proximity      2
# 100                             contextual proximity      2
# 101                                     processed by     10
# 102                             contextual proximity      2
# 103                             contextual proximity      4
# 104                    comprise,contextual proximity     12
# 105           are revealed with,contextual proximity     14
# 106                             contextual proximity      4
# 107                             contextual proximity      4
# 108                             contextual proximity      2
# 109                             contextual proximity      3
# 110                             contextual proximity      2
# 111                             contextual proximity      3
# 112                             contextual proximity      5
# 113                                         used for     10
# 114                             contextual proximity      2
# 115                  constitute,contextual proximity     14
# 116                             contextual proximity      2
# 117                             contextual proximity      4
# 118                             contextual proximity      4
# 119                             contextual proximity      4
# 120                             contextual proximity      2
# 121                             contextual proximity      5
# 122                             contextual proximity      5
# 123                                     is a type of     10
# 124                             contextual proximity      2
# 125                 composed of,contextual proximity     12
# 126                             contextual proximity      3
# 127                             contextual proximity      2
# 128                             contextual proximity      4
# 129                             contextual proximity      3
# 130                             contextual proximity      4
# 131                             contextual proximity      4
# 132                             contextual proximity      3
# 133              be analyzed by,contextual proximity     14
# 134                             contextual proximity      2
# 135                             contextual proximity      5
# 136                             contextual proximity      5
# 137                             contextual proximity      2
# 138                  listed for,contextual proximity     15
# 139                             contextual proximity      6
# 140                             contextual proximity      3
# 141                             contextual proximity      3
# 142                             contextual proximity      3
# 143                             contextual proximity      3
# 144                             contextual proximity      3
# 145                             contextual proximity      3
# 146                             contextual proximity      3
# 147                             contextual proximity      3
# 148                             contextual proximity      3
# 149                             contextual proximity      3
# 150                             contextual proximity      3
# 151                             contextual proximity      3
# 152                             contextual proximity      3
# 153                             contextual proximity     15
# 154                             contextual proximity      3
# 155                             contextual proximity      2
# 156                                         examined     10
# 157                             contextual proximity      3
# 158                             contextual proximity      5
# 159                             contextual proximity      4
# 160                             contextual proximity      2
# 161                             contextual proximity      4
# 162                             contextual proximity      4
# 163                     empower,contextual proximity     14
# 164                             contextual proximity      2
# 165                             contextual proximity      2
# 166        area of active study,contextual proximity     13
# 167                             contextual proximity      5
# 168                             contextual proximity      3
# 169                     creates,contextual proximity     13
# 170                             contextual proximity      3
# 171                        uses,contextual proximity     13
# 172                             contextual proximity      3
# 173                             contextual proximity      3
# 174                             contextual proximity      3
# 175                             contextual proximity      3
# 176                             contextual proximity      3
# 177                             contextual proximity      3
# 178                             contextual proximity      3
# 179                             contextual proximity      3
# 180                             contextual proximity      2
# 181                             contextual proximity      3
# 182                             contextual proximity      5
# 183                             contextual proximity      5
# 184                             assists in analyzing     10
# 185                             contextual proximity      3
# 186                             contextual proximity      2
# 187                             contextual proximity      5
# 188                               has application in     10
# 189                                are hidden within     10
# 190                             contextual proximity      5
# 191                             contextual proximity      2
# 192                                      accentuates     10
# 193                             contextual proximity      3
# 194      damage-free method for,contextual proximity     12
# 195                             contextual proximity      2
# 196                             contextual proximity      2
# 197                             contextual proximity      2
# 198                             contextual proximity      2
# 199                             contextual proximity      2
# 200                                     simulated to     10
# 201                             contextual proximity     10
# 202                             contextual proximity      5
# 203          has application in,contextual proximity     15
# 204          has application in,contextual proximity     15
# 205      promise for conserving,contextual proximity     15
# 206                             contextual proximity      5
# 207                             contextual proximity      5
# 208                is a type of,contextual proximity     15
# 209                             contextual proximity      5
# 210                             contextual proximity      5
# 211                             contextual proximity      5
# 212                             contextual proximity      5
# 213       promise for restoring,contextual proximity     15
# 214                             contextual proximity      5
# 215                             contextual proximity      5
# 216                             contextual proximity      5
# 217                             contextual proximity      5
# 218                             contextual proximity      5
# 219                             contextual proximity      5
# 220          has application in,contextual proximity     15
# 221                             contextual proximity      5
# 222                             contextual proximity      5
# 223  helps to avoid damage from,contextual proximity     15
# 224                 advances in,contextual proximity     25
# 225                             contextual proximity      5
# 226                             contextual proximity      5
# 227                    involves,contextual proximity     13
# 228                 advances in,contextual proximity     15
# 229                             contextual proximity      5
# 230                             contextual proximity      5
# 231                             contextual proximity      5
# 232                             contextual proximity      5
# 233                             contextual proximity      5
# 234                             contextual proximity      5
# 235                             contextual proximity      5
# 236                             contextual proximity      5
# 237                             contextual proximity      5
# 238                             contextual proximity      5
# 239                             contextual proximity      5
# 240                             contextual proximity      5
# 241                             contextual proximity      2
# 242                             contextual proximity      5
# 243                             contextual proximity      2
# 244                             contextual proximity      3
# 245                precursor to,contextual proximity     15
# 246                                    emits rays to     10
# 247                             contextual proximity      3

# %%
nodes = pd.concat([dfg['node_1'], dfg['node_2']], axis=0).unique()
nodes.shape
# Out:
# (75,)

# %%
import networkx as nx
G = nx.Graph()

## Add nodes to the graph
for node in nodes:
    G.add_node(
        str(node)
    )

## Add edges to the graph
for index, row in dfg.iterrows():
    G.add_edge(
        str(row["node_1"]),
        str(row["node_2"]),
        title=row["edge"],
        weight=row['count']/4
    )

# %%
communities_generator = nx.community.girvan_newman(G)
top_level_communities = next(communities_generator)
next_level_communities = next(communities_generator)
communities = sorted(map(sorted, next_level_communities))
print("Number of Communities = ", len(communities))
print(communities)
# Out:
# Number of Communities =  6
# [['1', 'number', 'single'], ['3d image', 'advanced algorithms', 'ct imaging', 'faint text or images', 'layers within scanned data', 'object', 'scanned data', 'scanning', 'segmentation & layer detection', 'texture mapping', 'x-ray source'], ['4', '6'], ['algorithm', 'contrast', 'digital algorithms', 'hidden text or details', 'image processing techniques', 'ink deposits', 'intensity', 'layers', 'layers of interest', 'machine learning', 'physical layers', 'texture', 'virtual layers', 'writing materials'], ['algorithms', 'analysis', 'archeology', 'artifacts', 'conservation of cultural heritage', 'cultural artifacts', 'deep learning algorithms', 'delicate writings and artifacts', 'digital procedure', 'digital reconstruction algorithms', 'forensic medicine', 'fragile items', 'herculaneum scrolls', 'historical knowledge', 'images', 'imaging technologies', 'innards', 'intelligence', 'internal structure imaging', 'layers of text', 'limits', 'material composition', 'medical imaging', 'micro-ct', 'objects', 'physical handling', 'research', 'researcher', 'researchers', 'resolution limitations', 'scientific research', 'sealed items', 'synchrotron radiation', 'tangible contents', 'unwrap', 'virtual unwrapping', 'wildlife detection systems', 'x-ray computed tomography (ct)', 'x-ray ct scan'], ['brief history of virtual unwrapping techniques', 'conclusion', 'how it works', 'introduction', 'references', 'virtual unwrapping techniques']]

# %%
import seaborn as sns
palette = "hls"

## Now add these colors to communities and make another dataframe
def colors2Community(communities) -> pd.DataFrame:
    ## Define a color palette
    p = sns.color_palette(palette, len(communities)).as_hex()
    random.shuffle(p)
    rows = []
    group = 0
    for community in communities:
        color = p.pop()
        group += 1
        for node in community:
            rows += [{"node": node, "color": color, "group": group}]
    df_colors = pd.DataFrame(rows)
    return df_colors


colors = colors2Community(communities)
colors
# Out:
#                                               node    color  group
# 0                                                1  #d3db57      1
# 1                                           number  #d3db57      1
# 2                                           single  #d3db57      1
# 3                                         3d image  #5f57db      2
# 4                              advanced algorithms  #5f57db      2
# 5                                       ct imaging  #5f57db      2
# 6                             faint text or images  #5f57db      2
# 7                       layers within scanned data  #5f57db      2
# 8                                           object  #5f57db      2
# 9                                     scanned data  #5f57db      2
# 10                                        scanning  #5f57db      2
# 11                  segmentation & layer detection  #5f57db      2
# 12                                 texture mapping  #5f57db      2
# 13                                    x-ray source  #5f57db      2
# 14                                               4  #db57d3      3
# 15                                               6  #db57d3      3
# 16                                       algorithm  #57d3db      4
# 17                                        contrast  #57d3db      4
# 18                              digital algorithms  #57d3db      4
# 19                          hidden text or details  #57d3db      4
# 20                     image processing techniques  #57d3db      4
# 21                                    ink deposits  #57d3db      4
# 22                                       intensity  #57d3db      4
# 23                                          layers  #57d3db      4
# 24                              layers of interest  #57d3db      4
# 25                                machine learning  #57d3db      4
# 26                                 physical layers  #57d3db      4
# 27                                         texture  #57d3db      4
# 28                                  virtual layers  #57d3db      4
# 29                               writing materials  #57d3db      4
# 30                                      algorithms  #57db5f      5
# 31                                        analysis  #57db5f      5
# 32                                      archeology  #57db5f      5
# 33                                       artifacts  #57db5f      5
# 34               conservation of cultural heritage  #57db5f      5
# 35                              cultural artifacts  #57db5f      5
# 36                        deep learning algorithms  #57db5f      5
# 37                 delicate writings and artifacts  #57db5f      5
# 38                               digital procedure  #57db5f      5
# 39               digital reconstruction algorithms  #57db5f      5
# 40                               forensic medicine  #57db5f      5
# 41                                   fragile items  #57db5f      5
# 42                             herculaneum scrolls  #57db5f      5
# 43                            historical knowledge  #57db5f      5
# 44                                          images  #57db5f      5
# 45                            imaging technologies  #57db5f      5
# 46                                         innards  #57db5f      5
# 47                                    intelligence  #57db5f      5
# 48                      internal structure imaging  #57db5f      5
# 49                                  layers of text  #57db5f      5
# 50                                          limits  #57db5f      5
# 51                            material composition  #57db5f      5
# 52                                 medical imaging  #57db5f      5
# 53                                        micro-ct  #57db5f      5
# 54                                         objects  #57db5f      5
# 55                               physical handling  #57db5f      5
# 56                                        research  #57db5f      5
# 57                                      researcher  #57db5f      5
# 58                                     researchers  #57db5f      5
# 59                          resolution limitations  #57db5f      5
# 60                             scientific research  #57db5f      5
# 61                                    sealed items  #57db5f      5
# 62                           synchrotron radiation  #57db5f      5
# 63                               tangible contents  #57db5f      5
# 64                                          unwrap  #57db5f      5
# 65                              virtual unwrapping  #57db5f      5
# 66                      wildlife detection systems  #57db5f      5
# 67                  x-ray computed tomography (ct)  #57db5f      5
# 68                                   x-ray ct scan  #57db5f      5
# 69  brief history of virtual unwrapping techniques  #db5f57      6
# 70                                      conclusion  #db5f57      6
# 71                                    how it works  #db5f57      6
# 72                                    introduction  #db5f57      6
# 73                                      references  #db5f57      6
# 74                   virtual unwrapping techniques  #db5f57      6

# %%
for index, row in colors.iterrows():
    G.nodes[row['node']]['group'] = row['group']
    G.nodes[row['node']]['color'] = row['color']
    G.nodes[row['node']]['size'] = G.degree[row['node']]

# %%
# !pip install pyvis

from pyvis.network import Network

graph_output_directory = "./docs/index.html"

net = Network(
    notebook=False,
    # bgcolor="#1a1a1a",
    cdn_resources="remote",
    height="900px",
    width="100%",
    select_menu=True,
    # font_color="#cccccc",
    filter_menu=False,
)

net.from_nx(G)
# net.repulsion(node_distance=150, spring_length=400)
net.force_atlas_2based(central_gravity=0.015, gravity=-31)
# net.barnes_hut(gravity=-18100, central_gravity=5.05, spring_length=380)
net.show_buttons(filter_=["physics"])

net.show(graph_output_directory, notebook=False)
# Out:
# ./docs/index.html
